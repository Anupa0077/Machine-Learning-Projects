# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn import metrics

# %%
df = pd.read_csv("Car details v3.csv")

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df1 = df.dropna()
df1.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df1.shape
# Out:
# (7906, 13)

# %%
df1['seats'].value_counts()
# Out:
# seats
# 5.0     6254
# 7.0     1120
# 8.0      235
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: count, dtype: int64

# %%
row_with_14_seats = df1[df1['seats'] == 14]
row_with_14_seats = pd.DataFrame(row_with_14_seats)
row_with_14_seats
# Out:
#                                          name  year  selling_price  km_driven  \
# 4575  Tata Winger Deluxe - Flat Roof (Non-AC)  2010         235000      50000
#
#         fuel seller_type transmission        owner     mileage   engine  \
# 4575  Diesel  Individual       Manual  First Owner  10.71 kmpl  1948 CC
#
#      max_power               torque  seats
# 4575    90 bhp  190Nm@ 2000-3000rpm   14.0

# %%
df1['torque'].value_counts()
# Out:
# torque
# 190Nm@ 2000rpm             530
# 200Nm@ 1750rpm             445
# 90Nm@ 3500rpm              405
# 113Nm@ 4200rpm             223
# 114Nm@ 4000rpm             171
#                           ...
# 128Nm@ 3100rpm               1
# 72.9Nm@ 2250rpm              1
# 155 Nm at 1600-2800 rpm      1
# 510Nm@ 1600-2800rpm          1
# 96  Nm at 3000  rpm          1
# Name: count, Length: 441, dtype: int64

# %%
len(df1['torque'].unique())
# Out:
# 441

# %%
data = df1.copy()

# %%
def extract_torque_rpm(value):
    # Replace 'at' with '@' for consistency
    value = value.replace(' at ', ' @ ')
    parts = value.split('@')
    torque = parts[0].strip()
    rpm = parts[1].strip() if len(parts) > 1 else None
    return pd.Series([torque, rpm])

# Apply the function to the 'torque' column
df1[['torque_value', 'rpm']] = df1['torque'].apply(extract_torque_rpm)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16108\2083686979.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['torque_value', 'rpm']] = df1['torque'].apply(extract_torque_rpm)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16108\2083686979.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['torque_value', 'rpm']] = df1['torque'].apply(extract_torque_rpm)

# %%
df1
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df1['torque'].unique()
# Out:
# array(['190Nm@ 2000rpm', '250Nm@ 1500-2500rpm', '12.7@ 2,700(kgm@ rpm)',
#        '22.4 kgm at 1750-2750rpm', '11.5@ 4,500(kgm@ rpm)',
#        '113.75nm@ 4000rpm', '7.8@ 4,500(kgm@ rpm)', '59Nm@ 2500rpm',
#        '170Nm@ 1800-2400rpm', '160Nm@ 2000rpm', '248Nm@ 2250rpm',
#        '78Nm@ 4500rpm', '84Nm@ 3500rpm', '115Nm@ 3500-3600rpm',
#        '200Nm@ 1750rpm', '62Nm@ 3000rpm', '219.7Nm@ 1500-2750rpm',
#        '114Nm@ 3500rpm', '115Nm@ 4000rpm', '69Nm@ 3500rpm',
#        '172.5Nm@ 1750rpm', '6.1kgm@ 3000rpm', '114.7Nm@ 4000rpm',
#        '60Nm@ 3500rpm', '90Nm@ 3500rpm', '151Nm@ 4850rpm',
#        '104Nm@ 4000rpm', '320Nm@ 1700-2700rpm', '250Nm@ 1750-2500rpm',
#        '145Nm@ 4600rpm', '146Nm@ 4800rpm', '343Nm@ 1400-3400rpm',
#        '200Nm@ 1400-3400rpm', '200Nm@ 1250-4000rpm',
#        '400Nm@ 2000-2500rpm', '138Nm@ 4400rpm', '360Nm@ 1200-3400rpm',
#        '200Nm@ 1200-3600rpm', '380Nm@ 1750-2500rpm', '173Nm@ 4000rpm',
#        '400Nm@ 1750-3000rpm', '400Nm@ 1400-2800rpm',
# ...

# %%
df1.head(15)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
df1['torque_value'] = df1['torque_value'].str.extract('(\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16108\1178031561.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df1['torque_value'] = df1['torque_value'].str.extract('(\d+)').astype(float)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16108\1178031561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['torque_value'] = df1['torque_value'].str.extract('(\d+)').astype(float)

# %%
df1.head(15)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
df1.loc[df1['torque_value'] < 50, 'torque_value'] *= 9.80665

# %%
df1
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df1['torque_value'].value_counts()
# Out:
# torque_value
# 200.0000    693
# 190.0000    673
# 90.0000     449
# 114.0000    373
# 113.0000    369
#            ...
# 313.8128      1
# 123.0000      1
# 490.0000      1
# 228.0000      1
# 480.0000      1
# Name: count, Length: 183, dtype: int64

# %%
df1['torque_value'].describe()
# Out:
# count    7906.000000
# mean      177.195849
# std        90.989104
# min        39.226600
# 25%       111.000000
# 50%       170.000000
# 75%       205.000000
# max       789.000000
# Name: torque_value, dtype: float64

# %%
row_with_39_torque = df1[df1['torque_value'] ==39.226600]
row_with_39_torque = pd.DataFrame(row_with_39_torque)
row_with_39_torque
# Out:
#               name  year  selling_price  km_driven    fuel seller_type  \
# 5878  Tata Nano Lx  2011          70000      40000  Petrol  Individual
#
#      transmission        owner    mileage  engine max_power           torque  \
# 5878       Manual  First Owner  26.0 kmpl  624 CC    35 bhp  4.8kgm@ 3000rpm
#
#       seats  torque_value      rpm
# 5878    4.0       39.2266  3000rpm

# %%
df1['torque_value'] = df1['torque_value'].round(2)
df1.tail(15)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16108\3333848319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['torque_value'] = df1['torque_value'].round(2)
#                                               name  year  selling_price  \
# 8113  Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV  2010         425000
# 8114                               Maruti Alto LXi  2011         200000
# 8115                                 Maruti 800 AC  1997          40000
# 8116                    Maruti Alto K10 VXI Airbag  2017         340000
# 8117                        Maruti Swift Dzire VDI  2015         625000
# 8118                             Hyundai i20 Magna  2013         380000
# ...

# %%
data2 = df1.copy()
data3 = data2.copy()
data2.head()
data3
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
def Clean_and_Average_RPM(rpm):
    if pd.isna(rpm):
        return None
    # Extract all numeric parts
    numeric_parts = re.findall(r'\d+', rpm)
    numeric_parts = list(map(int, numeric_parts))
    if len(numeric_parts) > 1:
        # Check if the values are in a range format (e.g., 1800-3000)
        if '-' in rpm:
            return sum(numeric_parts) / len(numeric_parts)  # Average the range
        else:
            return max(numeric_parts)  # Use the maximum value if not a range
    return numeric_parts[0]

# %%
data2['rpm'] = data2['rpm'].apply(Clean_and_Average_RPM)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 data2['rpm'] = data2['rpm'].apply(Clean_and_Average_RPM)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7906 entries, 0 to 8127
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
#  13  torque_value   7906 non-null   float64
#  14  rpm            7864 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 988.2+ KB

# %%
import re
def clean_and_average_rpm(rpm):
    if pd.isna(rpm):
        return None
    # Extract all numeric parts
    numeric_parts = re.findall(r'\d+', rpm)
    numeric_parts = list(map(int, numeric_parts))
    if len(numeric_parts) > 1:
        return sum(numeric_parts) / len(numeric_parts)  # Average the values
    return numeric_parts[0]

# %%
df1['rpm'] = df1['rpm'].apply(clean_and_average_rpm)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16108\4129499856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rpm'] = df1['rpm'].apply(clean_and_average_rpm)

# %%
df1
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df1.head(15)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
data2.head(15)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
df1['rpm'].describe()
# Out:
# count    7864.000000
# mean     2765.997912
# std      1097.597990
# min         1.000000
# 25%      2000.000000
# 50%      2375.000000
# 75%      4000.000000
# max      5000.000000
# Name: rpm, dtype: float64

# %%
row_with_1_rpm = df1[df1['rpm'] ==1]
row_with_1_rpm = pd.DataFrame(row_with_1_rpm)
row_with_1_rpm
# Out:
#                                                  name  year  selling_price  \
# 845                       Ford Fiesta 1.4 ZXi Duratec  2011         200000
# 889                       Ford Fusion 1.4 TDCi Diesel  2009         150000
# 1023                     Ford Fiesta EXi 1.4 TDCi Ltd  2011         300000
# 1282                      Ford Fiesta 1.4 Duratec EXI  2006         140000
# 1404                     Ford Fiesta EXi 1.4 TDCi Ltd  2011         170000
# 1659           Mahindra Renault Logan 1.5 Diesel DLSX  2009         200000
# 1663            Mahindra Renault Logan 1.5 DLX Diesel  2007         175000
# 1990  Mercedes-Benz New C-Class C 220 CDI Elegance MT  2018        2950000
# 1998                    Mahindra Logan Diesel 1.5 DLE  2011         180000
# 2435                 Ford Fusion Plus 1.4 TDCi Diesel  2008          90000
# 2612                     Ford Fiesta EXi 1.4 TDCi Ltd  2011         275000
# ...

# %%
df_with_less_than_500_rpm = df1[df1['rpm'] <= 500]
df_with_less_than_500_rpm
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 6     Maruti Wagon R LXI DUO BSIII  2007          96000     175000     LPG
# 226         Hyundai i20 1.2 Sportz  2012         275000      93000  Petrol
# 242             Hyundai Accent GLE  2007          80000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8076      Maruti Wagon R LXI BSIII  2006         150000      50000  Petrol
# 8079                Tata Indigo LS  2007          90177     129000  Diesel
# 8082  Ford Fiesta 1.4 Duratorq EXI  2007         125000     110000  Diesel
# 8104     Honda City 2017-2020 VTEC  2006         160000      70000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
#
# ...

# %%
data2
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data[['torque_value', 'rpm']] = data['torque'].apply(extract_torque_rpm)
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data['cleaned_rpm'] = data['rpm'].apply(Clean_and_Average_RPM)

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
def clean_and_average_rpm(rpm):
    if pd.isna(rpm):
        return None
    # Remove commas from the string
    rpm = rpm.replace(',', '')
    # Extract all numeric parts
    numeric_parts = re.findall(r'\d+', rpm)
    numeric_parts = list(map(int, numeric_parts))
    if len(numeric_parts) > 1:
        # Check if the values are in a range format (e.g., 1800-3000)
        if '-' in rpm:
            return sum(numeric_parts) / len(numeric_parts)  # Average the range
        else:
            return max(numeric_parts)  # Use the maximum value if not a range
    return numeric_parts[0]

# %%
data['cleaned_rpm_1'] = data['rpm'].apply(clean_and_average_rpm)

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...
